# %%
import networkx as nx
import numpy as np
from fugu import Scaffold
from grid_rw_brick import random_source, binary2unary, grid_ring

scaffold = Scaffold()
scaffold.add_brick(random_source(N=3, T=10, name='source'), 'input')
scaffold.add_brick(binary2unary(name='convert'))
scaffold.add_brick(grid_ring(name='grid', ringSize=7))

# %%
scaffold.lay_bricks()

# %%
len([[node, scaffold.graph.nodes[node]] for node in scaffold.graph.nodes])
# Out:
# 159

# %%
[[node, scaffold.graph.nodes[node]] for node in scaffold.graph.nodes]
# Out:
# [['source_complete',
#   {'index': -1, 'threshold': -1.0, 'decay': 0.0, 'p': 1.0, 'potential': 0.0}],
#  ['source_0', {'index': 0, 'threshold': -1.0, 'decay': 0.0, 'p': 0.5}],
#  ['source_1', {'index': 1, 'threshold': -1.0, 'decay': 0.0, 'p': 0.5}],
#  ['source_2', {'index': 2, 'threshold': -1.0, 'decay': 0.0, 'p': 0.5}],
#  ['convert_complete',
#   {'index': -1, 'threshold': 0.0, 'decay': 0.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_0',
#   {'index': 0, 'threshold': 0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_1',
#   {'index': 1, 'threshold': 1, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_2',
#   {'index': 2, 'threshold': 1, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_3',
#   {'index': 3, 'threshold': 2, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_4',
#   {'index': 4, 'threshold': 1, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_5',
#   {'index': 5, 'threshold': 2, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_6',
#   {'index': 6, 'threshold': 2, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['convert_7',
#   {'index': 7, 'threshold': 3, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_complete',
#   {'index': -1, 'threshold': 0.0, 'decay': 0.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_0',
#   {'index': 0, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_1',
#   {'index': 1, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_2',
#   {'index': 2, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_3',
#   {'index': 3, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_4',
#   {'index': 4, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_5',
#   {'index': 5, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_6',
#   {'index': 6, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_7',
#   {'index': 7, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_8',
#   {'index': 8, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_9',
#   {'index': 9, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_10',
#   {'index': 10, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_11',
#   {'index': 11, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_12',
#   {'index': 12, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_13',
#   {'index': 13, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_14',
#   {'index': 14, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_15',
#   {'index': 15, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_16',
#   {'index': 16, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_17',
#   {'index': 17, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_18',
#   {'index': 18, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_19',
#   {'index': 19, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_20',
#   {'index': 20, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_21',
#   {'index': 21, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_22',
#   {'index': 22, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_23',
#   {'index': 23, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_24',
#   {'index': 24, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_25',
#   {'index': 25, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_26',
#   {'index': 26, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_27',
#   {'index': 27, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_28',
#   {'index': 28, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_29',
#   {'index': 29, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_30',
#   {'index': 30, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_31',
#   {'index': 31, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_32',
#   {'index': 32, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_33',
#   {'index': 33, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_34',
#   {'index': 34, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_35',
#   {'index': 35, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_36',
#   {'index': 36, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_37',
#   {'index': 37, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_38',
#   {'index': 38, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_39',
#   {'index': 39, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_40',
#   {'index': 40, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_41',
#   {'index': 41, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_42',
#   {'index': 42, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_43',
#   {'index': 43, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_44',
#   {'index': 44, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_45',
#   {'index': 45, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_46',
#   {'index': 46, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_47',
#   {'index': 47, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_48',
#   {'index': 48, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_49',
#   {'index': 49, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_50',
#   {'index': 50, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_51',
#   {'index': 51, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_52',
#   {'index': 52, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_53',
#   {'index': 53, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_54',
#   {'index': 54, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_55',
#   {'index': 55, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_56',
#   {'index': 56, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_57',
#   {'index': 57, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_58',
#   {'index': 58, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_59',
#   {'index': 59, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_60',
#   {'index': 60, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_61',
#   {'index': 61, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_62',
#   {'index': 62, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_63',
#   {'index': 63, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_64',
#   {'index': 64, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_65',
#   {'index': 65, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_66',
#   {'index': 66, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_67',
#   {'index': 67, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_68',
#   {'index': 68, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_69',
#   {'index': 69, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_70',
#   {'index': 70, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_71',
#   {'index': 71, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_72',
#   {'index': 72, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_73',
#   {'index': 73, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_74',
#   {'index': 74, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_75',
#   {'index': 75, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_76',
#   {'index': 76, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_77',
#   {'index': 77, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_78',
#   {'index': 78, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_79',
#   {'index': 79, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_80',
#   {'index': 80, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_81',
#   {'index': 81, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_82',
#   {'index': 82, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_83',
#   {'index': 83, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_84',
#   {'index': 84, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_85',
#   {'index': 85, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_86',
#   {'index': 86, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_87',
#   {'index': 87, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_88',
#   {'index': 88, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_89',
#   {'index': 89, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_90',
#   {'index': 90, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_91',
#   {'index': 91, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_92',
#   {'index': 92, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_93',
#   {'index': 93, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_94',
#   {'index': 94, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_95',
#   {'index': 95, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_96',
#   {'index': 96, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_97',
#   {'index': 97, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_98',
#   {'index': 98, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_99',
#   {'index': 99, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_100',
#   {'index': 100, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_101',
#   {'index': 101, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_102',
#   {'index': 102, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_103',
#   {'index': 103, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_104',
#   {'index': 104, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_105',
#   {'index': 105, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_106',
#   {'index': 106, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_107',
#   {'index': 107, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_108',
#   {'index': 108, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_109',
#   {'index': 109, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_110',
#   {'index': 110, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_111',
#   {'index': 111, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_112',
#   {'index': 112, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_113',
#   {'index': 113, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_114',
#   {'index': 114, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_115',
#   {'index': 115, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_116',
#   {'index': 116, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_117',
#   {'index': 117, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_118',
#   {'index': 118, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_119',
#   {'index': 119, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_120',
#   {'index': 120, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_121',
#   {'index': 121, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_122',
#   {'index': 122, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_123',
#   {'index': 123, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_124',
#   {'index': 124, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_125',
#   {'index': 125, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_126',
#   {'index': 126, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_127',
#   {'index': 127, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_128',
#   {'index': 128, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_129',
#   {'index': 129, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_130',
#   {'index': 130, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_131',
#   {'index': 131, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_132',
#   {'index': 132, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_133',
#   {'index': 133, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_134',
#   {'index': 134, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_135',
#   {'index': 135, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_136',
#   {'index': 136, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_137',
#   {'index': 137, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_138',
#   {'index': 138, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_139',
#   {'index': 139, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_140',
#   {'index': 140, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_141',
#   {'index': 141, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_142',
#   {'index': 142, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_143',
#   {'index': 143, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}],
#  ['grid_144',
#   {'index': 144, 'threshold': 1.0, 'decay': 1.0, 'p': 1.0, 'potential': 0.0}]]

# %%
[[edge, scaffold.graph.edges[edge]] for edge in scaffold.graph.edges]
# Out:
# [[('source_complete', 'source_0'), {'weight': -5.0, 'delay': 10}],
#  [('source_complete', 'source_1'), {'weight': -5.0, 'delay': 10}],
#  [('source_complete', 'source_2'), {'weight': -5.0, 'delay': 10}],
#  [('source_complete', 'source_complete'), {'weight': -5.0, 'delay': 1}],
#  [('source_complete', 'convert_complete'), {'weight': 1.0, 'delay': 1}],
#  [('source_0', 'convert_0'), {'weight': -1, 'delay': 1.0}],
#  [('source_0', 'convert_1'), {'weight': -1, 'delay': 1.0}],
#  [('source_0', 'convert_2'), {'weight': -1, 'delay': 1.0}],
#  [('source_0', 'convert_3'), {'weight': -1, 'delay': 1.0}],
#  [('source_0', 'convert_4'), {'weight': 1, 'delay': 1.0}],
#  [('source_0', 'convert_5'), {'weight': 1, 'delay': 1.0}],
#  [('source_0', 'convert_6'), {'weight': 1, 'delay': 1.0}],
#  [('source_0', 'convert_7'), {'weight': 1, 'delay': 1.0}],
#  [('source_1', 'convert_0'), {'weight': -1, 'delay': 1.0}],
#  [('source_1', 'convert_1'), {'weight': -1, 'delay': 1.0}],
#  [('source_1', 'convert_2'), {'weight': 1, 'delay': 1.0}],
#  [('source_1', 'convert_3'), {'weight': 1, 'delay': 1.0}],
#  [('source_1', 'convert_4'), {'weight': -1, 'delay': 1.0}],
#  [('source_1', 'convert_5'), {'weight': -1, 'delay': 1.0}],
#  [('source_1', 'convert_6'), {'weight': 1, 'delay': 1.0}],
#  [('source_1', 'convert_7'), {'weight': 1, 'delay': 1.0}],
#  [('source_2', 'convert_0'), {'weight': -1, 'delay': 1.0}],
#  [('source_2', 'convert_1'), {'weight': 1, 'delay': 1.0}],
#  [('source_2', 'convert_2'), {'weight': -1, 'delay': 1.0}],
#  [('source_2', 'convert_3'), {'weight': 1, 'delay': 1.0}],
#  [('source_2', 'convert_4'), {'weight': -1, 'delay': 1.0}],
#  [('source_2', 'convert_5'), {'weight': 1, 'delay': 1.0}],
#  [('source_2', 'convert_6'), {'weight': -1, 'delay': 1.0}],
#  [('source_2', 'convert_7'), {'weight': 1, 'delay': 1.0}],
#  [('convert_complete', 'grid_complete'), {'weight': 1.0, 'delay': 1}],
#  [('convert_0', 'grid_49'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_50'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_51'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_52'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_53'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_54'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_55'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_56'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_57'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_58'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_59'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_60'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_61'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_62'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_63'), {'weight': 0.5, 'delay': 1}],
#  [('convert_0', 'grid_64'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_65'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_66'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_67'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_68'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_69'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_70'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_71'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_72'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_73'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_74'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_75'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_76'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_77'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_78'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_79'), {'weight': 0.5, 'delay': 1}],
#  [('convert_1', 'grid_80'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_81'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_82'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_83'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_84'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_85'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_86'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_87'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_88'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_89'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_90'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_91'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_92'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_93'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_94'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_95'), {'weight': 0.5, 'delay': 1}],
#  [('convert_2', 'grid_96'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_97'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_98'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_99'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_100'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_101'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_102'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_103'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_104'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_105'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_106'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_107'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_108'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_109'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_110'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_111'), {'weight': 0.5, 'delay': 1}],
#  [('convert_3', 'grid_112'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_113'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_114'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_115'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_116'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_117'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_118'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_119'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_120'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_121'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_122'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_123'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_124'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_125'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_126'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_127'), {'weight': 0.5, 'delay': 1}],
#  [('convert_4', 'grid_128'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_129'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_130'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_131'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_132'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_133'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_134'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_135'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_136'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_137'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_138'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_139'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_140'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_141'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_142'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_143'), {'weight': 0.5, 'delay': 1}],
#  [('convert_5', 'grid_144'), {'weight': 0.5, 'delay': 1}],
#  [('grid_0', 'grid_0'), {'weight': 1.1, 'delay': 2}],
#  [('grid_0', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_42'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_0', 'grid_49'), {'weight': 0.6, 'delay': 1}],
#  [('grid_0', 'grid_65'), {'weight': 0.6, 'delay': 1}],
#  [('grid_0', 'grid_81'), {'weight': 0.6, 'delay': 1}],
#  [('grid_0', 'grid_97'), {'weight': 0.6, 'delay': 1}],
#  [('grid_0', 'grid_113'), {'weight': 0.6, 'delay': 1}],
#  [('grid_0', 'grid_129'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_1'), {'weight': 1.1, 'delay': 2}],
#  [('grid_1', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_42'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_1', 'grid_50'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_66'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_82'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_98'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_114'), {'weight': 0.6, 'delay': 1}],
#  [('grid_1', 'grid_130'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_2'), {'weight': 1.1, 'delay': 2}],
#  [('grid_2', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_2', 'grid_51'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_67'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_83'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_99'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_115'), {'weight': 0.6, 'delay': 1}],
#  [('grid_2', 'grid_131'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_3'), {'weight': 1.1, 'delay': 2}],
#  [('grid_3', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_3', 'grid_49'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_65'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_81'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_97'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_113'), {'weight': 0.6, 'delay': 1}],
#  [('grid_3', 'grid_129'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_4'), {'weight': 1.1, 'delay': 2}],
#  [('grid_4', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_4', 'grid_50'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_66'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_82'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_98'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_114'), {'weight': 0.6, 'delay': 1}],
#  [('grid_4', 'grid_130'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_5'), {'weight': 1.1, 'delay': 2}],
#  [('grid_5', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_6'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_5', 'grid_51'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_67'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_83'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_99'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_115'), {'weight': 0.6, 'delay': 1}],
#  [('grid_5', 'grid_131'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_6'), {'weight': 1.1, 'delay': 2}],
#  [('grid_6', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_6', 'grid_52'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_68'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_84'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_100'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_116'), {'weight': 0.6, 'delay': 1}],
#  [('grid_6', 'grid_132'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_7'), {'weight': 1.1, 'delay': 2}],
#  [('grid_7', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_7', 'grid_53'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_69'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_85'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_101'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_117'), {'weight': 0.6, 'delay': 1}],
#  [('grid_7', 'grid_133'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_8'), {'weight': 1.1, 'delay': 2}],
#  [('grid_8', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_8', 'grid_54'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_70'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_86'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_102'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_118'), {'weight': 0.6, 'delay': 1}],
#  [('grid_8', 'grid_134'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_9'), {'weight': 1.1, 'delay': 2}],
#  [('grid_9', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_9', 'grid_55'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_71'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_87'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_103'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_119'), {'weight': 0.6, 'delay': 1}],
#  [('grid_9', 'grid_135'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_10'), {'weight': 1.1, 'delay': 2}],
#  [('grid_10', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_10', 'grid_53'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_69'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_85'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_101'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_117'), {'weight': 0.6, 'delay': 1}],
#  [('grid_10', 'grid_133'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_11'), {'weight': 1.1, 'delay': 2}],
#  [('grid_11', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_11', 'grid_54'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_70'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_86'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_102'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_118'), {'weight': 0.6, 'delay': 1}],
#  [('grid_11', 'grid_134'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_12'), {'weight': 1.1, 'delay': 2}],
#  [('grid_12', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_12', 'grid_55'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_71'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_87'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_103'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_119'), {'weight': 0.6, 'delay': 1}],
#  [('grid_12', 'grid_135'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_13'), {'weight': 1.1, 'delay': 2}],
#  [('grid_13', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_6'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_13', 'grid_56'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_72'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_88'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_104'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_120'), {'weight': 0.6, 'delay': 1}],
#  [('grid_13', 'grid_136'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_14'), {'weight': 1.1, 'delay': 2}],
#  [('grid_14', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_14', 'grid_57'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_73'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_89'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_105'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_121'), {'weight': 0.6, 'delay': 1}],
#  [('grid_14', 'grid_137'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_15'), {'weight': 1.1, 'delay': 2}],
#  [('grid_15', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_15', 'grid_58'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_74'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_90'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_106'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_122'), {'weight': 0.6, 'delay': 1}],
#  [('grid_15', 'grid_138'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_16'), {'weight': 1.1, 'delay': 2}],
#  [('grid_16', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_8'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_16', 'grid_59'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_75'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_91'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_107'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_123'), {'weight': 0.6, 'delay': 1}],
#  [('grid_16', 'grid_139'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_17'), {'weight': 1.1, 'delay': 2}],
#  [('grid_17', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_9'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_17', 'grid_57'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_73'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_89'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_105'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_121'), {'weight': 0.6, 'delay': 1}],
#  [('grid_17', 'grid_137'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_18'), {'weight': 1.1, 'delay': 2}],
#  [('grid_18', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_10'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_18', 'grid_58'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_74'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_90'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_106'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_122'), {'weight': 0.6, 'delay': 1}],
#  [('grid_18', 'grid_138'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_19'), {'weight': 1.1, 'delay': 2}],
#  [('grid_19', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_11'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_19', 'grid_59'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_75'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_91'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_107'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_123'), {'weight': 0.6, 'delay': 1}],
#  [('grid_19', 'grid_139'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_20'), {'weight': 1.1, 'delay': 2}],
#  [('grid_20', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_13'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_12'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_20', 'grid_60'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_76'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_92'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_108'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_124'), {'weight': 0.6, 'delay': 1}],
#  [('grid_20', 'grid_140'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_21'), {'weight': 1.1, 'delay': 2}],
#  [('grid_21', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_21', 'grid_49'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_65'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_81'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_97'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_113'), {'weight': 0.6, 'delay': 1}],
#  [('grid_21', 'grid_129'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_22'), {'weight': 1.1, 'delay': 2}],
#  [('grid_22', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_14'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_22', 'grid_50'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_66'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_82'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_98'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_114'), {'weight': 0.6, 'delay': 1}],
#  [('grid_22', 'grid_130'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_23'), {'weight': 1.1, 'delay': 2}],
#  [('grid_23', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_15'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_23', 'grid_51'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_67'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_83'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_99'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_115'), {'weight': 0.6, 'delay': 1}],
#  [('grid_23', 'grid_131'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_24'), {'weight': 1.1, 'delay': 2}],
#  [('grid_24', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_16'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_24', 'grid_49'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_65'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_81'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_97'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_113'), {'weight': 0.6, 'delay': 1}],
#  [('grid_24', 'grid_129'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_25'), {'weight': 1.1, 'delay': 2}],
#  [('grid_25', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_17'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_25', 'grid_50'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_66'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_82'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_98'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_114'), {'weight': 0.6, 'delay': 1}],
#  [('grid_25', 'grid_130'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_26'), {'weight': 1.1, 'delay': 2}],
#  [('grid_26', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_18'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_26', 'grid_51'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_67'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_83'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_99'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_115'), {'weight': 0.6, 'delay': 1}],
#  [('grid_26', 'grid_131'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_27'), {'weight': 1.1, 'delay': 2}],
#  [('grid_27', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_20'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_19'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_27', 'grid_52'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_68'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_84'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_100'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_116'), {'weight': 0.6, 'delay': 1}],
#  [('grid_27', 'grid_132'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_28'), {'weight': 1.1, 'delay': 2}],
#  [('grid_28', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_28', 'grid_53'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_69'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_85'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_101'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_117'), {'weight': 0.6, 'delay': 1}],
#  [('grid_28', 'grid_133'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_29'), {'weight': 1.1, 'delay': 2}],
#  [('grid_29', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_21'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_29', 'grid_54'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_70'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_86'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_102'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_118'), {'weight': 0.6, 'delay': 1}],
#  [('grid_29', 'grid_134'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_30'), {'weight': 1.1, 'delay': 2}],
#  [('grid_30', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_22'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_30', 'grid_55'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_71'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_87'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_103'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_119'), {'weight': 0.6, 'delay': 1}],
#  [('grid_30', 'grid_135'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_31'), {'weight': 1.1, 'delay': 2}],
#  [('grid_31', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_23'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_31', 'grid_53'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_69'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_85'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_101'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_117'), {'weight': 0.6, 'delay': 1}],
#  [('grid_31', 'grid_133'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_32'), {'weight': 1.1, 'delay': 2}],
#  [('grid_32', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_24'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_32', 'grid_54'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_70'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_86'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_102'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_118'), {'weight': 0.6, 'delay': 1}],
#  [('grid_32', 'grid_134'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_33'), {'weight': 1.1, 'delay': 2}],
#  [('grid_33', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_25'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_33', 'grid_55'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_71'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_87'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_103'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_119'), {'weight': 0.6, 'delay': 1}],
#  [('grid_33', 'grid_135'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_34'), {'weight': 1.1, 'delay': 2}],
#  [('grid_34', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_27'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_26'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_34', 'grid_56'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_72'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_88'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_104'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_120'), {'weight': 0.6, 'delay': 1}],
#  [('grid_34', 'grid_136'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_35'), {'weight': 1.1, 'delay': 2}],
#  [('grid_35', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_42'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_35', 'grid_57'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_73'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_89'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_105'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_121'), {'weight': 0.6, 'delay': 1}],
#  [('grid_35', 'grid_137'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_36'), {'weight': 1.1, 'delay': 2}],
#  [('grid_36', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_28'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_36', 'grid_58'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_74'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_90'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_106'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_122'), {'weight': 0.6, 'delay': 1}],
#  [('grid_36', 'grid_138'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_37'), {'weight': 1.1, 'delay': 2}],
#  [('grid_37', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_29'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_37', 'grid_59'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_75'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_91'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_107'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_123'), {'weight': 0.6, 'delay': 1}],
#  [('grid_37', 'grid_139'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_38'), {'weight': 1.1, 'delay': 2}],
#  [('grid_38', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_30'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_38', 'grid_57'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_73'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_89'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_105'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_121'), {'weight': 0.6, 'delay': 1}],
#  [('grid_38', 'grid_137'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_39'), {'weight': 1.1, 'delay': 2}],
#  [('grid_39', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_31'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_39', 'grid_58'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_74'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_90'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_106'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_122'), {'weight': 0.6, 'delay': 1}],
#  [('grid_39', 'grid_138'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_40'), {'weight': 1.1, 'delay': 2}],
#  [('grid_40', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_32'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_40', 'grid_59'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_75'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_91'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_107'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_123'), {'weight': 0.6, 'delay': 1}],
#  [('grid_40', 'grid_139'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_41'), {'weight': 1.1, 'delay': 2}],
#  [('grid_41', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_34'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_33'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_41', 'grid_60'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_76'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_92'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_108'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_124'), {'weight': 0.6, 'delay': 1}],
#  [('grid_41', 'grid_140'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_42'), {'weight': 1.1, 'delay': 2}],
#  [('grid_42', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_42', 'grid_61'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_77'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_93'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_109'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_125'), {'weight': 0.6, 'delay': 1}],
#  [('grid_42', 'grid_141'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_43'), {'weight': 1.1, 'delay': 2}],
#  [('grid_43', 'grid_42'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_35'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_1'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_43', 'grid_62'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_78'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_94'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_110'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_126'), {'weight': 0.6, 'delay': 1}],
#  [('grid_43', 'grid_142'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_44'), {'weight': 1.1, 'delay': 2}],
#  [('grid_44', 'grid_43'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_36'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_2'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_44', 'grid_63'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_79'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_95'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_111'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_127'), {'weight': 0.6, 'delay': 1}],
#  [('grid_44', 'grid_143'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_45'), {'weight': 1.1, 'delay': 2}],
#  [('grid_45', 'grid_44'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_37'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_3'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_45', 'grid_61'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_77'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_93'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_109'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_125'), {'weight': 0.6, 'delay': 1}],
#  [('grid_45', 'grid_141'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_46'), {'weight': 1.1, 'delay': 2}],
#  [('grid_46', 'grid_45'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_38'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_4'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_46', 'grid_62'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_78'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_94'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_110'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_126'), {'weight': 0.6, 'delay': 1}],
#  [('grid_46', 'grid_142'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_47'), {'weight': 1.1, 'delay': 2}],
#  [('grid_47', 'grid_46'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_48'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_39'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_5'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_6'), {'weight': 0.6, 'delay': 2}],
#  [('grid_47', 'grid_63'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_79'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_95'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_111'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_127'), {'weight': 0.6, 'delay': 1}],
#  [('grid_47', 'grid_143'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_48'), {'weight': 1.1, 'delay': 2}],
#  [('grid_48', 'grid_47'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_7'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_41'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_40'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_6'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_0'), {'weight': 0.6, 'delay': 2}],
#  [('grid_48', 'grid_64'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_80'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_96'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_112'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_128'), {'weight': 0.6, 'delay': 1}],
#  [('grid_48', 'grid_144'), {'weight': 0.6, 'delay': 1}],
#  [('grid_49', 'grid_0'), {'weight': -0.5, 'delay': 1}],
#  [('grid_49', 'grid_1'), {'weight': 0.6, 'delay': 1}],
#  [('grid_49', 'grid_3'), {'weight': -0.5, 'delay': 1}],
#  [('grid_49', 'grid_4'), {'weight': 0.6, 'delay': 1}],
#  [('grid_49', 'grid_21'), {'weight': -0.5, 'delay': 1}],
#  [('grid_49', 'grid_22'), {'weight': 0.6, 'delay': 1}],
#  [('grid_49', 'grid_24'), {'weight': -0.5, 'delay': 1}],
#  [('grid_49', 'grid_25'), {'weight': 0.6, 'delay': 1}],
#  [('grid_50', 'grid_1'), {'weight': -0.5, 'delay': 1}],
#  [('grid_50', 'grid_2'), {'weight': 0.6, 'delay': 1}],
#  [('grid_50', 'grid_4'), {'weight': -0.5, 'delay': 1}],
#  [('grid_50', 'grid_5'), {'weight': 0.6, 'delay': 1}],
#  [('grid_50', 'grid_22'), {'weight': -0.5, 'delay': 1}],
#  [('grid_50', 'grid_23'), {'weight': 0.6, 'delay': 1}],
#  [('grid_50', 'grid_25'), {'weight': -0.5, 'delay': 1}],
#  [('grid_50', 'grid_26'), {'weight': 0.6, 'delay': 1}],
#  [('grid_51', 'grid_2'), {'weight': -0.5, 'delay': 1}],
#  [('grid_51', 'grid_3'), {'weight': 0.6, 'delay': 1}],
#  [('grid_51', 'grid_5'), {'weight': -0.5, 'delay': 1}],
#  [('grid_51', 'grid_6'), {'weight': 0.6, 'delay': 1}],
#  [('grid_51', 'grid_23'), {'weight': -0.5, 'delay': 1}],
#  [('grid_51', 'grid_24'), {'weight': 0.6, 'delay': 1}],
#  [('grid_51', 'grid_26'), {'weight': -0.5, 'delay': 1}],
#  [('grid_51', 'grid_27'), {'weight': 0.6, 'delay': 1}],
#  [('grid_52', 'grid_6'), {'weight': -0.5, 'delay': 1}],
#  [('grid_52', 'grid_21'), {'weight': 0.6, 'delay': 1}],
#  [('grid_52', 'grid_27'), {'weight': -0.5, 'delay': 1}],
#  [('grid_53', 'grid_7'), {'weight': -0.5, 'delay': 1}],
#  [('grid_53', 'grid_8'), {'weight': 0.6, 'delay': 1}],
#  [('grid_53', 'grid_10'), {'weight': -0.5, 'delay': 1}],
#  [('grid_53', 'grid_11'), {'weight': 0.6, 'delay': 1}],
#  [('grid_53', 'grid_28'), {'weight': -0.5, 'delay': 1}],
#  [('grid_53', 'grid_29'), {'weight': 0.6, 'delay': 1}],
#  [('grid_53', 'grid_31'), {'weight': -0.5, 'delay': 1}],
#  [('grid_53', 'grid_32'), {'weight': 0.6, 'delay': 1}],
#  [('grid_54', 'grid_0'), {'weight': 0.6, 'delay': 1}],
#  [('grid_54', 'grid_8'), {'weight': -0.5, 'delay': 1}],
#  [('grid_54', 'grid_9'), {'weight': 0.6, 'delay': 1}],
#  [('grid_54', 'grid_11'), {'weight': -0.5, 'delay': 1}],
#  [('grid_54', 'grid_12'), {'weight': 0.6, 'delay': 1}],
#  [('grid_54', 'grid_29'), {'weight': -0.5, 'delay': 1}],
#  [('grid_54', 'grid_30'), {'weight': 0.6, 'delay': 1}],
#  [('grid_54', 'grid_32'), {'weight': -0.5, 'delay': 1}],
#  [('grid_54', 'grid_33'), {'weight': 0.6, 'delay': 1}],
#  [('grid_55', 'grid_9'), {'weight': -0.5, 'delay': 1}],
#  [('grid_55', 'grid_10'), {'weight': 0.6, 'delay': 1}],
#  [('grid_55', 'grid_12'), {'weight': -0.5, 'delay': 1}],
#  [('grid_55', 'grid_13'), {'weight': 0.6, 'delay': 1}],
#  [('grid_55', 'grid_30'), {'weight': -0.5, 'delay': 1}],
#  [('grid_55', 'grid_31'), {'weight': 0.6, 'delay': 1}],
#  [('grid_55', 'grid_33'), {'weight': -0.5, 'delay': 1}],
#  [('grid_55', 'grid_34'), {'weight': 0.6, 'delay': 1}],
#  [('grid_56', 'grid_7'), {'weight': 0.6, 'delay': 1}],
#  [('grid_56', 'grid_13'), {'weight': -0.5, 'delay': 1}],
#  [('grid_56', 'grid_28'), {'weight': 0.6, 'delay': 1}],
#  [('grid_56', 'grid_34'), {'weight': -0.5, 'delay': 1}],
#  [('grid_57', 'grid_14'), {'weight': -0.5, 'delay': 1}],
#  [('grid_57', 'grid_15'), {'weight': 0.6, 'delay': 1}],
#  [('grid_57', 'grid_17'), {'weight': -0.5, 'delay': 1}],
#  [('grid_57', 'grid_18'), {'weight': 0.6, 'delay': 1}],
#  [('grid_57', 'grid_35'), {'weight': -0.5, 'delay': 1}],
#  [('grid_57', 'grid_36'), {'weight': 0.6, 'delay': 1}],
#  [('grid_57', 'grid_38'), {'weight': -0.5, 'delay': 1}],
#  [('grid_57', 'grid_39'), {'weight': 0.6, 'delay': 1}],
#  [('grid_58', 'grid_15'), {'weight': -0.5, 'delay': 1}],
#  [('grid_58', 'grid_16'), {'weight': 0.6, 'delay': 1}],
#  [('grid_58', 'grid_18'), {'weight': -0.5, 'delay': 1}],
#  [('grid_58', 'grid_19'), {'weight': 0.6, 'delay': 1}],
#  [('grid_58', 'grid_36'), {'weight': -0.5, 'delay': 1}],
#  [('grid_58', 'grid_37'), {'weight': 0.6, 'delay': 1}],
#  [('grid_58', 'grid_39'), {'weight': -0.5, 'delay': 1}],
#  [('grid_58', 'grid_40'), {'weight': 0.6, 'delay': 1}],
#  [('grid_59', 'grid_16'), {'weight': -0.5, 'delay': 1}],
#  [('grid_59', 'grid_17'), {'weight': 0.6, 'delay': 1}],
#  [('grid_59', 'grid_19'), {'weight': -0.5, 'delay': 1}],
#  [('grid_59', 'grid_20'), {'weight': 0.6, 'delay': 1}],
#  [('grid_59', 'grid_37'), {'weight': -0.5, 'delay': 1}],
#  [('grid_59', 'grid_38'), {'weight': 0.6, 'delay': 1}],
#  [('grid_59', 'grid_40'), {'weight': -0.5, 'delay': 1}],
#  [('grid_59', 'grid_41'), {'weight': 0.6, 'delay': 1}],
#  [('grid_60', 'grid_14'), {'weight': 0.6, 'delay': 1}],
#  [('grid_60', 'grid_20'), {'weight': -0.5, 'delay': 1}],
#  [('grid_60', 'grid_35'), {'weight': 0.6, 'delay': 1}],
#  [('grid_60', 'grid_41'), {'weight': -0.5, 'delay': 1}],
#  [('grid_61', 'grid_42'), {'weight': -0.5, 'delay': 1}],
#  [('grid_61', 'grid_43'), {'weight': 0.6, 'delay': 1}],
#  [('grid_61', 'grid_45'), {'weight': -0.5, 'delay': 1}],
#  [('grid_61', 'grid_46'), {'weight': 0.6, 'delay': 1}],
#  [('grid_62', 'grid_43'), {'weight': -0.5, 'delay': 1}],
#  [('grid_62', 'grid_44'), {'weight': 0.6, 'delay': 1}],
#  [('grid_62', 'grid_46'), {'weight': -0.5, 'delay': 1}],
#  [('grid_62', 'grid_47'), {'weight': 0.6, 'delay': 1}],
#  [('grid_63', 'grid_44'), {'weight': -0.5, 'delay': 1}],
#  [('grid_63', 'grid_45'), {'weight': 0.6, 'delay': 1}],
#  [('grid_63', 'grid_47'), {'weight': -0.5, 'delay': 1}],
#  [('grid_63', 'grid_48'), {'weight': 0.6, 'delay': 1}],
#  [('grid_64', 'grid_42'), {'weight': 0.6, 'delay': 1}],
#  [('grid_64', 'grid_48'), {'weight': -0.5, 'delay': 1}],
#  [('grid_65', 'grid_0'), {'weight': -0.5, 'delay': 1}],
#  [('grid_65', 'grid_2'), {'weight': 0.6, 'delay': 1}],
#  [('grid_65', 'grid_3'), {'weight': -0.5, 'delay': 1}],
#  [('grid_65', 'grid_6'), {'weight': 0.6, 'delay': 1}],
#  [('grid_65', 'grid_21'), {'weight': -0.5, 'delay': 1}],
#  [('grid_65', 'grid_23'), {'weight': 0.6, 'delay': 1}],
#  [('grid_65', 'grid_24'), {'weight': -0.5, 'delay': 1}],
#  [('grid_65', 'grid_27'), {'weight': 0.6, 'delay': 1}],
#  [('grid_66', 'grid_0'), {'weight': 0.6, 'delay': 1}],
#  [('grid_66', 'grid_1'), {'weight': -0.5, 'delay': 1}],
#  [('grid_66', 'grid_3'), {'weight': 0.6, 'delay': 1}],
#  [('grid_66', 'grid_4'), {'weight': -0.5, 'delay': 1}],
#  [('grid_66', 'grid_21'), {'weight': 0.6, 'delay': 1}],
#  [('grid_66', 'grid_22'), {'weight': -0.5, 'delay': 1}],
#  [('grid_66', 'grid_24'), {'weight': 0.6, 'delay': 1}],
#  [('grid_66', 'grid_25'), {'weight': -0.5, 'delay': 1}],
#  [('grid_67', 'grid_1'), {'weight': 0.6, 'delay': 1}],
#  [('grid_67', 'grid_2'), {'weight': -0.5, 'delay': 1}],
#  [('grid_67', 'grid_4'), {'weight': 0.6, 'delay': 1}],
#  [('grid_67', 'grid_5'), {'weight': -0.5, 'delay': 1}],
#  [('grid_67', 'grid_22'), {'weight': 0.6, 'delay': 1}],
#  [('grid_67', 'grid_23'), {'weight': -0.5, 'delay': 1}],
#  [('grid_67', 'grid_25'), {'weight': 0.6, 'delay': 1}],
#  [('grid_67', 'grid_26'), {'weight': -0.5, 'delay': 1}],
#  [('grid_68', 'grid_5'), {'weight': 0.6, 'delay': 1}],
#  [('grid_68', 'grid_6'), {'weight': -0.5, 'delay': 1}],
#  [('grid_68', 'grid_26'), {'weight': 0.6, 'delay': 1}],
#  [('grid_68', 'grid_27'), {'weight': -0.5, 'delay': 1}],
#  [('grid_69', 'grid_7'), {'weight': -0.5, 'delay': 1}],
#  [('grid_69', 'grid_9'), {'weight': 0.6, 'delay': 1}],
#  [('grid_69', 'grid_10'), {'weight': -0.5, 'delay': 1}],
#  [('grid_69', 'grid_13'), {'weight': 0.6, 'delay': 1}],
#  [('grid_69', 'grid_28'), {'weight': -0.5, 'delay': 1}],
#  [('grid_69', 'grid_30'), {'weight': 0.6, 'delay': 1}],
#  [('grid_69', 'grid_31'), {'weight': -0.5, 'delay': 1}],
#  [('grid_69', 'grid_34'), {'weight': 0.6, 'delay': 1}],
#  [('grid_70', 'grid_7'), {'weight': 0.6, 'delay': 1}],
#  [('grid_70', 'grid_8'), {'weight': -0.5, 'delay': 1}],
#  [('grid_70', 'grid_10'), {'weight': 0.6, 'delay': 1}],
#  [('grid_70', 'grid_11'), {'weight': -0.5, 'delay': 1}],
#  [('grid_70', 'grid_28'), {'weight': 0.6, 'delay': 1}],
#  [('grid_70', 'grid_29'), {'weight': -0.5, 'delay': 1}],
#  [('grid_70', 'grid_31'), {'weight': 0.6, 'delay': 1}],
#  [('grid_70', 'grid_32'), {'weight': -0.5, 'delay': 1}],
#  [('grid_71', 'grid_8'), {'weight': 0.6, 'delay': 1}],
#  [('grid_71', 'grid_9'), {'weight': -0.5, 'delay': 1}],
#  [('grid_71', 'grid_11'), {'weight': 0.6, 'delay': 1}],
#  [('grid_71', 'grid_12'), {'weight': -0.5, 'delay': 1}],
#  [('grid_71', 'grid_29'), {'weight': 0.6, 'delay': 1}],
#  [('grid_71', 'grid_30'), {'weight': -0.5, 'delay': 1}],
#  [('grid_71', 'grid_32'), {'weight': 0.6, 'delay': 1}],
#  [('grid_71', 'grid_33'), {'weight': -0.5, 'delay': 1}],
#  [('grid_72', 'grid_12'), {'weight': 0.6, 'delay': 1}],
#  [('grid_72', 'grid_13'), {'weight': -0.5, 'delay': 1}],
#  [('grid_72', 'grid_33'), {'weight': 0.6, 'delay': 1}],
#  [('grid_72', 'grid_34'), {'weight': -0.5, 'delay': 1}],
#  [('grid_73', 'grid_14'), {'weight': -0.5, 'delay': 1}],
#  [('grid_73', 'grid_16'), {'weight': 0.6, 'delay': 1}],
#  [('grid_73', 'grid_17'), {'weight': -0.5, 'delay': 1}],
#  [('grid_73', 'grid_20'), {'weight': 0.6, 'delay': 1}],
#  [('grid_73', 'grid_35'), {'weight': -0.5, 'delay': 1}],
#  [('grid_73', 'grid_37'), {'weight': 0.6, 'delay': 1}],
#  [('grid_73', 'grid_38'), {'weight': -0.5, 'delay': 1}],
#  [('grid_73', 'grid_41'), {'weight': 0.6, 'delay': 1}],
#  [('grid_74', 'grid_14'), {'weight': 0.6, 'delay': 1}],
#  [('grid_74', 'grid_15'), {'weight': -0.5, 'delay': 1}],
#  [('grid_74', 'grid_17'), {'weight': 0.6, 'delay': 1}],
#  [('grid_74', 'grid_18'), {'weight': -0.5, 'delay': 1}],
#  [('grid_74', 'grid_35'), {'weight': 0.6, 'delay': 1}],
#  [('grid_74', 'grid_36'), {'weight': -0.5, 'delay': 1}],
#  [('grid_74', 'grid_38'), {'weight': 0.6, 'delay': 1}],
#  [('grid_74', 'grid_39'), {'weight': -0.5, 'delay': 1}],
#  [('grid_75', 'grid_15'), {'weight': 0.6, 'delay': 1}],
#  [('grid_75', 'grid_16'), {'weight': -0.5, 'delay': 1}],
#  [('grid_75', 'grid_18'), {'weight': 0.6, 'delay': 1}],
#  [('grid_75', 'grid_19'), {'weight': -0.5, 'delay': 1}],
#  [('grid_75', 'grid_36'), {'weight': 0.6, 'delay': 1}],
#  [('grid_75', 'grid_37'), {'weight': -0.5, 'delay': 1}],
#  [('grid_75', 'grid_39'), {'weight': 0.6, 'delay': 1}],
#  [('grid_75', 'grid_40'), {'weight': -0.5, 'delay': 1}],
#  [('grid_76', 'grid_19'), {'weight': 0.6, 'delay': 1}],
#  [('grid_76', 'grid_20'), {'weight': -0.5, 'delay': 1}],
#  [('grid_76', 'grid_40'), {'weight': 0.6, 'delay': 1}],
#  [('grid_76', 'grid_41'), {'weight': -0.5, 'delay': 1}],
#  [('grid_77', 'grid_42'), {'weight': -0.5, 'delay': 1}],
#  [('grid_77', 'grid_44'), {'weight': 0.6, 'delay': 1}],
#  [('grid_77', 'grid_45'), {'weight': -0.5, 'delay': 1}],
#  [('grid_78', 'grid_42'), {'weight': 0.6, 'delay': 1}],
#  [('grid_78', 'grid_43'), {'weight': -0.5, 'delay': 1}],
#  [('grid_78', 'grid_45'), {'weight': 0.6, 'delay': 1}],
#  [('grid_78', 'grid_46'), {'weight': -0.5, 'delay': 1}],
#  [('grid_78', 'grid_48'), {'weight': 0.6, 'delay': 1}],
#  [('grid_79', 'grid_43'), {'weight': 0.6, 'delay': 1}],
#  [('grid_79', 'grid_44'), {'weight': -0.5, 'delay': 1}],
#  [('grid_79', 'grid_46'), {'weight': 0.6, 'delay': 1}],
#  [('grid_79', 'grid_47'), {'weight': -0.5, 'delay': 1}],
#  [('grid_80', 'grid_47'), {'weight': 0.6, 'delay': 1}],
#  [('grid_80', 'grid_48'), {'weight': -0.5, 'delay': 1}],
#  [('grid_81', 'grid_0'), {'weight': -0.5, 'delay': 1}],
#  [('grid_81', 'grid_3'), {'weight': -0.5, 'delay': 1}],
#  [('grid_81', 'grid_7'), {'weight': 0.6, 'delay': 1}],
#  [('grid_81', 'grid_10'), {'weight': 0.6, 'delay': 1}],
#  [('grid_81', 'grid_21'), {'weight': -0.5, 'delay': 1}],
#  [('grid_81', 'grid_24'), {'weight': -0.5, 'delay': 1}],
#  [('grid_81', 'grid_28'), {'weight': 0.6, 'delay': 1}],
#  [('grid_81', 'grid_31'), {'weight': 0.6, 'delay': 1}],
#  [('grid_82', 'grid_1'), {'weight': -0.5, 'delay': 1}],
#  [('grid_82', 'grid_4'), {'weight': -0.5, 'delay': 1}],
#  [('grid_82', 'grid_8'), {'weight': 0.6, 'delay': 1}],
#  [('grid_82', 'grid_11'), {'weight': 0.6, 'delay': 1}],
#  [('grid_82', 'grid_22'), {'weight': -0.5, 'delay': 1}],
#  [('grid_82', 'grid_25'), {'weight': -0.5, 'delay': 1}],
#  [('grid_82', 'grid_29'), {'weight': 0.6, 'delay': 1}],
#  [('grid_82', 'grid_32'), {'weight': 0.6, 'delay': 1}],
#  [('grid_83', 'grid_2'), {'weight': -0.5, 'delay': 1}],
#  [('grid_83', 'grid_5'), {'weight': -0.5, 'delay': 1}],
#  [('grid_83', 'grid_9'), {'weight': 0.6, 'delay': 1}],
#  [('grid_83', 'grid_12'), {'weight': 0.6, 'delay': 1}],
#  [('grid_83', 'grid_23'), {'weight': -0.5, 'delay': 1}],
#  [('grid_83', 'grid_26'), {'weight': -0.5, 'delay': 1}],
#  [('grid_83', 'grid_30'), {'weight': 0.6, 'delay': 1}],
#  [('grid_83', 'grid_33'), {'weight': 0.6, 'delay': 1}],
#  [('grid_84', 'grid_6'), {'weight': -0.5, 'delay': 1}],
#  [('grid_84', 'grid_13'), {'weight': 0.6, 'delay': 1}],
#  [('grid_84', 'grid_27'), {'weight': -0.5, 'delay': 1}],
#  [('grid_84', 'grid_34'), {'weight': 0.6, 'delay': 1}],
#  [('grid_85', 'grid_7'), {'weight': -0.5, 'delay': 1}],
#  [('grid_85', 'grid_10'), {'weight': -0.5, 'delay': 1}],
#  [('grid_85', 'grid_14'), {'weight': 0.6, 'delay': 1}],
#  [('grid_85', 'grid_17'), {'weight': 0.6, 'delay': 1}],
#  [('grid_85', 'grid_28'), {'weight': -0.5, 'delay': 1}],
#  [('grid_85', 'grid_31'), {'weight': -0.5, 'delay': 1}],
#  [('grid_85', 'grid_35'), {'weight': 0.6, 'delay': 1}],
#  [('grid_85', 'grid_38'), {'weight': 0.6, 'delay': 1}],
#  [('grid_86', 'grid_8'), {'weight': -0.5, 'delay': 1}],
#  [('grid_86', 'grid_11'), {'weight': -0.5, 'delay': 1}],
#  [('grid_86', 'grid_15'), {'weight': 0.6, 'delay': 1}],
#  [('grid_86', 'grid_18'), {'weight': 0.6, 'delay': 1}],
#  [('grid_86', 'grid_29'), {'weight': -0.5, 'delay': 1}],
#  ...]

# %%
result = scaffold.evaluate(backend='ds')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-cf353244f101> in <module>
# ----> 1 result = scaffold.evaluate(backend='ds')
#
# ~/prog/Fugu/code/fugu.py in evaluate(self, max_runtime, backend, record_all)
#     303         if backend == 'ds':
#     304             from ds import run_simulation
# --> 305             injection_values = self._create_ds_injection()
#     306             for node in self.circuit.nodes:
#     307                 if 'layer' in self.circuit.nodes[node] and self.circuit.nodes[node]['layer'] == 'output':
#
# ~/prog/Fugu/code/fugu.py in _create_ds_injection(self)
#     274         for input_node in input_nodes:
#     275             input_spikes = self.circuit.nodes[input_node]['brick'].get_input_value()
# --> 276             for t in range(0, input_spikes.shape[-1]):
#     277                 if t not in injection_tensors:
#     278                     injection_tensors[t] = torch.zeros((self.graph.number_of_nodes(),)).float()
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
scaffold.summary()

# %%
num_nodes=len(scaffold.graph.nodes)
result=nx.get_node_attributes(scaffold.graph, 'decay')
list(result.values())
a=np.array(list(result.values()))
nodes_decay=np.array(list(nx.get_node_attributes(scaffold.graph, 'decay').values()))
nodes_decay.shape[0]

# %%
nodes_decay=np.array(list(nx.get_node_attributes(scaffold.graph, 'decay').values()))
nodes_v=np.array(list(nx.get_node_attributes(scaffold.graph, 'potential').values()))
nodes_vt=np.array(list(nx.get_node_attributes(scaffold.graph, 'threshold').values()))
nodes_prob=np.array(list(nx.get_node_attributes(scaffold.graph, 'p').values()))
nodes_vr=np.zeros(num_nodes, )

# %%
nodes_vr.shape
